# %%
# !pip install spotipy

import pandas as pd
import numpy as np
import requests
import json
import spotipy
from pprint import pprint
from spotipy.oauth2 import SpotifyClientCredentials
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: spotipy in c:\users\valerie\anaconda3\lib\site-packages (2.16.1)
# Requirement already satisfied: six>=1.10.0 in c:\users\valerie\anaconda3\lib\site-packages (from spotipy) (1.15.0)
# Requirement already satisfied: requests>=2.20.0 in c:\users\valerie\anaconda3\lib\site-packages (from spotipy) (2.24.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\valerie\anaconda3\lib\site-packages (from requests>=2.20.0->spotipy) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\valerie\anaconda3\lib\site-packages (from requests>=2.20.0->spotipy) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\valerie\anaconda3\lib\site-packages (from requests>=2.20.0->spotipy) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\valerie\anaconda3\lib\site-packages (from requests>=2.20.0->spotipy) (3.0.4)

# %%
test_df = pd.read_csv("../Resources/Final_2019_Chart.csv")
test_df.head()
# Out:
#    2019_bb_rank    artist_name
# 0             1    Post Malone
# 1             2  Ariana Grande
# 2             3  Billie Eilish
# 3             4         Khalid
# 4             5          Drake

# %%
test_df['name2'] = ""
test_df['genres'] = ""
test_df['popularity'] = ""
test_df['uri_spotify'] = ""
test_df['followers'] = ""

test_df.head()
# Out:
#    2019_bb_rank    artist_name name2 genres popularity uri_spotify followers
# 0             1    Post Malone
# 1             2  Ariana Grande
# 2             3  Billie Eilish
# 3             4         Khalid
# 4             5          Drake

# %%
user_id= 
token= 
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(user_id,token))

# %%
params= {
    "name2": "name", 
    "popularity": "popularity",
    "genres": "genres",
    "uri_spotify": "uri",
    "followers": "followers"
}

# %%
for index, row in test_df[:101].iterrows():

    # get artist_name from df
    person = row['artist_name']

    # add keyword to params dict
    params['keyword'] = person

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {person}.")
    results = spotify.search(q=f'artist: {person}', type='artist')
    
    artist_data = results['artists']['items']
    
    try:
        #print(f"Artist {person} is in dataset")
        #print(f"Trying to get name")
        test_df.loc[index, 'name2'] = artist_data[0]['name']
        #print(f"Trying to get popularity")
        test_df.loc[index, 'popularity'] = artist_data[0]['popularity']
        #print(f"Trying to get genres")
        #print(artist_data[0]['genres'])
        #print(type(artist_data[0]['genres']))
        test_df.loc[index, 'genres'] = str(artist_data[0]['genres'])
        test_df.loc[index, 'uri_spotify'] = str(artist_data[0]['uri'])
        test_df.loc[index, 'followers'] = str(artist_data[0]['followers']['total'])
    except Exception as e:
        print(e)
# Out:
# Retrieving Results for Index 0: Post Malone.
# Retrieving Results for Index 1: Ariana Grande.
# Retrieving Results for Index 2: Billie Eilish.
# Retrieving Results for Index 3: Khalid.
# Retrieving Results for Index 4: Drake.
# Retrieving Results for Index 5: Travis Scott.
# Retrieving Results for Index 6: Ed Sheeran.
# Retrieving Results for Index 7: Taylor Swift.
# Retrieving Results for Index 8: Lil Nas X.
# Retrieving Results for Index 9: Halsey.
# Retrieving Results for Index 10: Jonas Brothers.
# Retrieving Results for Index 11: Juice WRLD.
# Retrieving Results for Index 12: Cardi B.
# Retrieving Results for Index 13: DaBaby.
# Retrieving Results for Index 14: BTS.
# Retrieving Results for Index 15: Panic! At The Disco.
# Retrieving Results for Index 16: Luke Combs.
# Retrieving Results for Index 17: Lil Baby.
# Retrieving Results for Index 18: Shawn Mendes.
# Retrieving Results for Index 19: Lizzo.
# Retrieving Results for Index 20: Meek Mill.
# Retrieving Results for Index 21: Queen.
# Retrieving Results for Index 22: Dan + Shay.
# Retrieving Results for Index 23: A Boogie Wit da Hoodie.
# Retrieving Results for Index 24: P!nk.
# Retrieving Results for Index 25: Chris Brown.
# Retrieving Results for Index 26: XXXTENTACION.
# Retrieving Results for Index 27: J. Cole.
# Retrieving Results for Index 28: Elton John.
# Retrieving Results for Index 29: Imagine Dragons.
# Retrieving Results for Index 30: Bad Bunny.
# Retrieving Results for Index 31: Kodak Black.
# Retrieving Results for Index 32: 21 Savage.
# Retrieving Results for Index 33: YoungBoy Never Broke Again.
# Retrieving Results for Index 34: Gunna.
# Retrieving Results for Index 35: Kane Brown.
# Retrieving Results for Index 36: Lady Gaga.
# Retrieving Results for Index 37: Marshmello.
# Retrieving Results for Index 38: Thomas Rhett.
# Retrieving Results for Index 39: Maroon 5.
# Retrieving Results for Index 40: Swae Lee.
# Retrieving Results for Index 41: Camila Cabello.
# Retrieving Results for Index 42: Sam Smith.
# Retrieving Results for Index 43: YNW Melly.
# Retrieving Results for Index 44: The Rolling Stones.
# Retrieving Results for Index 45: 5 Seconds Of Summer.
# Retrieving Results for Index 46: Lauren Daigle.
# Retrieving Results for Index 47: Lil Tecca.
# Retrieving Results for Index 48: Metallica.
# Retrieving Results for Index 49: Bruno Mars.
# Retrieving Results for Index 50: Young Thug.
# Retrieving Results for Index 51: Ella Mai.
# Retrieving Results for Index 52: Bradley Cooper.
# Retrieving Results for Index 53: Lewis Capaldi.
# Retrieving Results for Index 54: Eminem.
# Retrieving Results for Index 55: Jason Aldean.
# Retrieving Results for Index 56: NF.
# Retrieving Results for Index 57: Michael Buble.
# Retrieving Results for Index 58: Ava Max.
# Retrieving Results for Index 59: The Beatles.
# Retrieving Results for Index 60: Normani.
# Retrieving Results for Index 61: Florida Georgia Line.
# Retrieving Results for Index 62: twenty one pilots.
# Retrieving Results for Index 63: Billy Ray Cyrus.
# Retrieving Results for Index 64: Chris Stapleton.
# Retrieving Results for Index 65: Summer Walker.
# Retrieving Results for Index 66: Morgan Wallen.
# Retrieving Results for Index 67: Bastille.
# Retrieving Results for Index 68: Offset.
# Retrieving Results for Index 69: Trippie Redd.
# Retrieving Results for Index 70: Tyler, The Creator.
# Retrieving Results for Index 71: Future.
# Retrieving Results for Index 72: Lil Wayne.
# Retrieving Results for Index 73: Blake Shelton.
# Retrieving Results for Index 74: Justin Bieber.
# Retrieving Results for Index 75: City Girls.
# Retrieving Results for Index 76: Blueface.
# Retrieving Results for Index 77: Carrie Underwood.
# Retrieving Results for Index 78: Kanye West.
# Retrieving Results for Index 79: DJ Khaled.
# Retrieving Results for Index 80: Billy Joel.
# Retrieving Results for Index 81: Eagles.
# Retrieving Results for Index 82: Backstreet Boys.
# Retrieving Results for Index 83: Paul McCartney.
# Retrieving Results for Index 84: Megan Thee Stallion.
# Retrieving Results for Index 85: Maren Morris.
# Retrieving Results for Index 86: Bazzi.
# Retrieving Results for Index 87: Mustard.
# Retrieving Results for Index 88: 6ix9ine.
# Retrieving Results for Index 89: Kendrick Lamar.
# Retrieving Results for Index 90: Polo G.
# Retrieving Results for Index 91: Sheck Wes.
# Retrieving Results for Index 92: Migos.
# Retrieving Results for Index 93: Lil Uzi Vert.
# Retrieving Results for Index 94: Nipsey Hussle.
# Retrieving Results for Index 95: Fleetwood Mac.
# Retrieving Results for Index 96: The Weeknd.
# Retrieving Results for Index 97: Eric Church.
# Retrieving Results for Index 98: benny blanco.
# Retrieving Results for Index 99: Luke Bryan.

# %%
## New dataset matching top BB artists with Spotify API data

test_df.loc[test_df['name2'] != '']
# Out:
#     2019_bb_rank    artist_name          name2  \
# 0              1    Post Malone    Post Malone
# 1              2  Ariana Grande  Ariana Grande
# 2              3  Billie Eilish  Billie Eilish
# 3              4         Khalid         Khalid
# 4              5          Drake          Drake
# ..           ...            ...            ...
# 95            96  Fleetwood Mac  Fleetwood Mac
# 96            97     The Weeknd     The Weeknd
# 97            98    Eric Church    Eric Church
# 98            99   benny blanco   benny blanco
# 99           100     Luke Bryan     Luke Bryan
#
#                                                genres popularity  \
# 0                   ['dfw rap', 'melodic rap', 'rap']         95
# 1               ['dance pop', 'pop', 'post-teen pop']         99
# 2                               ['electropop', 'pop']         93
# 3                          ['alternative r&b', 'pop']         93
# 4   ['canadian hip hop', 'canadian pop', 'hip hop'...        100
# ..                                                ...        ...
# 95  ['album rock', 'classic rock', 'mellow gold', ...         88
# 96  ['canadian contemporary r&b', 'canadian pop', ...         96
# 97  ['contemporary country', 'country', 'country r...         78
# 98                   ['electropop', 'pop', 'pop rap']         85
# 99  ['contemporary country', 'country', 'country r...         80
#
#                               uri_spotify followers
# 0   spotify:artist:246dkjvS1zLTtiykXe5h60  29173640
# 1   spotify:artist:66CXWjxzNUsdJxJ2JdwvnR  52571724
# 2   spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH  34697267
# 3   spotify:artist:6LuN9FCkKOj5PcnpouEgny  12829933
# 4   spotify:artist:3TVXtAsR1Inumwj472S9r4  50593376
# ..                                    ...       ...
# 95  spotify:artist:08GQAI4eElDnROBrJRGE0X   5464936
# 96  spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ  25562055
# 97  spotify:artist:2IvkS5MXK0vPGnwyJsrEyV   2745679
# 98  spotify:artist:5CiGnKThu5ctn9pBxv7DGa    653196
# 99  spotify:artist:0BvkDsjIUla7X0k6CSWh1I   5822742
#
# [100 rows x 7 columns]

# %%
## Check Variable Types
test_df.dtypes
# Out:
# 2019_bb_rank     int64
# artist_name     object
# name2           object
# genres          object
# popularity      object
# uri_spotify     object
# followers       object
# dtype: object

# %%
## Data cleaning - transform variables to integers
test_df["popularity"]=test_df["popularity"].astype(int)
test_df["followers"]=test_df["followers"].astype(int)

# %%
## Understanding variety in genres category
test_df.genres.value_counts()
# Out:
# ['dance pop', 'pop', 'post-teen pop']                                               2
# ['pop', 'uk pop']                                                                   2
# ['dance pop', 'pop']                                                                2
# ['dance pop', 'pop', 'pop dance', 'post-teen pop']                                  2
# ['melodic rap', 'rap', 'trap']                                                      2
#                                                                                    ..
# ['contemporary country', 'texas country']                                           1
# ['canadian hip hop', 'canadian pop', 'hip hop', 'pop rap', 'rap', 'toronto rap']    1
# ['baton rouge rap', 'trap']                                                         1
# ['melodic rap', 'philly rap', 'rap', 'trap']                                        1
# ['contemporary country', 'pop']                                                     1
# Name: genres, Length: 91, dtype: int64

# %%
## Even though there is 1-100 rank on BB charts, these artists have similar rankings in Spotify Popularity
test_df.popularity.value_counts()
# Out:
# 80     8
# 83     8
# 84     7
# 91     7
# 92     6
# 90     6
# 86     5
# 85     5
# 93     5
# 89     5
# 78     4
# 88     4
# 95     4
# 99     3
# 96     3
# 79     3
# 87     2
# 76     2
# 94     2
# 82     2
# 81     2
# 75     2
# 73     1
# 100    1
# 77     1
# 97     1
# 71     1
# Name: popularity, dtype: int64

# %%
## Mean popularity of 100 artists
pop_avg = test_df["popularity"].mean()
print(pop_avg)
# Out:
# 86.6

# %%
## Median popularity of 100 artist
pop_med = test_df["popularity"].median()
print(pop_med)
# Out:
# 86.0

# %%
## Mean followers of 100 artists
foll_avg = test_df["followers"].mean()
print(foll_avg)
# Out:
# 11254196.7

# %%
## Median followers of 100 artist
foll_med = test_df["followers"].median()
print(foll_med)
# Out:
# 5570411.0

# %%
## min and max popularity score across billboard top 100
pop_min = test_df["popularity"].min()
pop_max = test_df["popularity"].max()

print(pop_min)
print(pop_max)
# Out:
# 71
# 100

# %%
## min and max followers across billboard top 100
foll_min = test_df["followers"].min()
foll_max = test_df["followers"].max()
total_foll = sum(test_df['followers'])

print(foll_min)
print(foll_max)
print(total_foll)
# Out:
# 161775
# 71783101
# 1125419670

# %%
## Who are the Billboard top 10
top_10_df = test_df.loc[test_df["2019_bb_rank"] < 11, :]
top_10_df
# Out:
#    2019_bb_rank    artist_name          name2  \
# 0             1    Post Malone    Post Malone
# 1             2  Ariana Grande  Ariana Grande
# 2             3  Billie Eilish  Billie Eilish
# 3             4         Khalid         Khalid
# 4             5          Drake          Drake
# 5             6   Travis Scott   Travis Scott
# 6             7     Ed Sheeran     Ed Sheeran
# 7             8   Taylor Swift   Taylor Swift
# 8             9      Lil Nas X      Lil Nas X
# 9            10         Halsey         Halsey
#
#                                               genres  popularity  \
# 0                  ['dfw rap', 'melodic rap', 'rap']          95
# 1              ['dance pop', 'pop', 'post-teen pop']          99
# 2                              ['electropop', 'pop']          93
# 3                         ['alternative r&b', 'pop']          93
# 4  ['canadian hip hop', 'canadian pop', 'hip hop'...         100
# 5                                            ['rap']          96
# 6                                  ['pop', 'uk pop']          94
# 7  ['dance pop', 'pop', 'pop dance', 'post-teen p...          95
# 8       ['country rap', 'lgbtq+ hip hop', 'pop rap']          79
# 9  ['dance pop', 'electropop', 'etherpop', 'indie...          91
#
#                              uri_spotify  followers
# 0  spotify:artist:246dkjvS1zLTtiykXe5h60   29173640
# 1  spotify:artist:66CXWjxzNUsdJxJ2JdwvnR   52571724
# 2  spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH   34697267
# 3  spotify:artist:6LuN9FCkKOj5PcnpouEgny   12829933
# 4  spotify:artist:3TVXtAsR1Inumwj472S9r4   50593376
# 5  spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY   13434540
# 6  spotify:artist:6eUKZXaKkcviH0Ku9w2n3V   71783101
# 7  spotify:artist:06HL4z0CvFAxyc27GXpf02   33485486
# 8  spotify:artist:7jVv8c5Fj3E9VhNjxT4snq    3624644
# 9  spotify:artist:26VFTg2z8YR0cCuwLzESi2   12622150

# %%
## What is the min-max and median pop scores and followers stats for top 10 bb artists?
pop_min_10 = top_10_df["popularity"].min()
pop_max_10 = top_10_df["popularity"].max()

print(pop_min_10)
print(pop_max_10)


foll_min_10 = top_10_df["followers"].min()
foll_max_10 = top_10_df["followers"].max()
total_foll_10 = sum(top_10_df['followers'])

print(foll_min_10)
print(foll_max_10)
print(total_foll_10)

pop_med_top = top_10_df["popularity"].median()
print(pop_med_top)

foll_med_top = top_10_df["followers"].median()
print(foll_med_top)
# Out:
# 79
# 100
# 3624644
# 71783101
# 314815861
# 94.5
# 31329563.0

# %%
## Who are the Billboard Bottom 10
bottom_10_df = test_df.loc[test_df["2019_bb_rank"] > 89, :]
bottom_10_df
# Out:
#     2019_bb_rank     artist_name           name2  \
# 89            90  Kendrick Lamar  Kendrick Lamar
# 90            91          Polo G          Polo G
# 91            92       Sheck Wes       Sheck Wes
# 92            93           Migos           Migos
# 93            94    Lil Uzi Vert    Lil Uzi Vert
# 94            95   Nipsey Hussle   Nipsey Hussle
# 95            96   Fleetwood Mac   Fleetwood Mac
# 96            97      The Weeknd      The Weeknd
# 97            98     Eric Church     Eric Church
# 98            99    benny blanco    benny blanco
# 99           100      Luke Bryan      Luke Bryan
#
#                                                genres  popularity  \
# 89  ['conscious hip hop', 'hip hop', 'rap', 'west ...          90
# 90                                    ['chicago rap']          90
# 91  ['rap', 'trap', 'underground hip hop', 'vapor ...          71
# 92  ['atl hip hop', 'hip hop', 'pop rap', 'rap', '...          84
# 93       ['melodic rap', 'philly rap', 'rap', 'trap']          92
# 94  ['conscious hip hop', 'gangster rap', 'hip hop...          76
# 95  ['album rock', 'classic rock', 'mellow gold', ...          88
# 96  ['canadian contemporary r&b', 'canadian pop', ...          96
# 97  ['contemporary country', 'country', 'country r...          78
# 98                   ['electropop', 'pop', 'pop rap']          85
# 99  ['contemporary country', 'country', 'country r...          80
#
#                               uri_spotify  followers
# 89  spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg   15770741
# 90  spotify:artist:6AgTAQt8XS6jRWi4sX7w49    2382140
# 91  spotify:artist:2RDOrhPqAM4jzTRCEb19qX     981104
# 92  spotify:artist:6oMuImdp5ZcFhWP0ESe6mG   10919803
# 93  spotify:artist:4O15NlyKLIASxsJ0PrXPfz   10065137
# 94  spotify:artist:0EeQBlQJFiAfJeVN2vT9s0    1750629
# 95  spotify:artist:08GQAI4eElDnROBrJRGE0X    5464936
# 96  spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ   25562055
# 97  spotify:artist:2IvkS5MXK0vPGnwyJsrEyV    2745679
# 98  spotify:artist:5CiGnKThu5ctn9pBxv7DGa     653196
# 99  spotify:artist:0BvkDsjIUla7X0k6CSWh1I    5822742

# %%
## What is the min-max and median pop scores and followers stats for bottom 10 bb artists?
pop_min_90 = bottom_10_df["popularity"].min()
pop_max_90 = bottom_10_df["popularity"].max()

print(pop_min_90)
print(pop_max_90)


foll_min_90 = bottom_10_df["followers"].min()
foll_max_90 = bottom_10_df["followers"].max()
total_foll_90 = sum(bottom_10_df['followers'])

print(foll_min_90)
print(foll_max_90)
print(total_foll_90)


pop_med_bottom = bottom_10_df["popularity"].median()
print(pop_med_bottom)

foll_med_bottom = bottom_10_df["followers"].median()
print(foll_med_bottom)
# Out:
# 71
# 96
# 653196
# 25562055
# 82118162
# 85.0
# 5464936.0

# %%
## Top artists in terms of Spotify Pop
pop_sort_df = test_df.sort_values("popularity", ascending=False)
pop_sort_df.head(10)
# Out:
#     2019_bb_rank    artist_name          name2  \
# 4              5          Drake          Drake
# 1              2  Ariana Grande  Ariana Grande
# 11            12     Juice WRLD     Juice WRLD
# 30            31      Bad Bunny      Bad Bunny
# 14            15            BTS            BTS
# 96            97     The Weeknd     The Weeknd
# 74            75  Justin Bieber  Justin Bieber
# 5              6   Travis Scott   Travis Scott
# 0              1    Post Malone    Post Malone
# 17            18       Lil Baby       Lil Baby
#
#                                                genres  popularity  \
# 4   ['canadian hip hop', 'canadian pop', 'hip hop'...         100
# 1               ['dance pop', 'pop', 'post-teen pop']          99
# 11                     ['chicago rap', 'melodic rap']          99
# 30              ['latin', 'reggaeton', 'trap latino']          99
# 14                       ['k-pop', 'k-pop boy group']          97
# 96  ['canadian contemporary r&b', 'canadian pop', ...          96
# 74           ['canadian pop', 'pop', 'post-teen pop']          96
# 5                                             ['rap']          96
# 0                   ['dfw rap', 'melodic rap', 'rap']          95
# 17                 ['atl hip hop', 'atl trap', 'rap']          95
#
#                               uri_spotify  followers
# 4   spotify:artist:3TVXtAsR1Inumwj472S9r4   50593376
# 1   spotify:artist:66CXWjxzNUsdJxJ2JdwvnR   52571724
# 11  spotify:artist:4MCBfE4596Uoi2O4DtmEMz   13266070
# 30  spotify:artist:4q3ewBCX7sLwd24euuV69X   26265604
# 14  spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX   24755789
# 96  spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ   25562055
# 74  spotify:artist:1uNFoZAHBGtllmzznpCI3s   39214943
# 5   spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY   13434540
# 0   spotify:artist:246dkjvS1zLTtiykXe5h60   29173640
# 17  spotify:artist:5f7VJjfbwm532GiveGC0ZK    5372519

# %%
## Top artists in terms of Spotify Followers
foll_sort_df = test_df.sort_values("followers", ascending=False)
foll_sort_df.head(10)
# Out:
#     2019_bb_rank      artist_name            name2  \
# 6              7       Ed Sheeran       Ed Sheeran
# 1              2    Ariana Grande    Ariana Grande
# 4              5            Drake            Drake
# 74            75    Justin Bieber    Justin Bieber
# 54            55           Eminem           Eminem
# 2              3    Billie Eilish    Billie Eilish
# 7              8     Taylor Swift     Taylor Swift
# 29            30  Imagine Dragons  Imagine Dragons
# 21            22            Queen            Queen
# 18            19     Shawn Mendes     Shawn Mendes
#
#                                                genres  popularity  \
# 6                                   ['pop', 'uk pop']          94
# 1               ['dance pop', 'pop', 'post-teen pop']          99
# 4   ['canadian hip hop', 'canadian pop', 'hip hop'...         100
# 74           ['canadian pop', 'pop', 'post-teen pop']          96
# 54              ['detroit hip hop', 'hip hop', 'rap']          94
# 2                               ['electropop', 'pop']          93
# 7   ['dance pop', 'pop', 'pop dance', 'post-teen p...          95
# 29                     ['modern rock', 'pop', 'rock']          90
# 21              ['classic rock', 'glam rock', 'rock']          90
# 18  ['canadian pop', 'dance pop', 'pop', 'post-tee...          91
#
#                               uri_spotify  followers
# 6   spotify:artist:6eUKZXaKkcviH0Ku9w2n3V   71783101
# 1   spotify:artist:66CXWjxzNUsdJxJ2JdwvnR   52571724
# 4   spotify:artist:3TVXtAsR1Inumwj472S9r4   50593376
# 74  spotify:artist:1uNFoZAHBGtllmzznpCI3s   39214943
# 54  spotify:artist:7dGJo4pcD2V6oG8kP0tJRR   39078037
# 2   spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH   34697267
# 7   spotify:artist:06HL4z0CvFAxyc27GXpf02   33485486
# 29  spotify:artist:53XhwfbYqKCa1cC15pYq2q   30723081
# 21  spotify:artist:1dfeR4HaWDbWqFHLkxsg1d   29836055
# 18  spotify:artist:7n2wHs1TKAczGzO7Dd2rGr   29743681

# %%
## Bottom artists in terms of Spotify Pop
pop_sort_low_df = test_df.sort_values("popularity", ascending=True)
pop_sort_low_df.head(10)
# Out:
#     2019_bb_rank       artist_name             name2  \
# 91            92         Sheck Wes         Sheck Wes
# 63            64   Billy Ray Cyrus   Billy Ray Cyrus
# 46            47     Lauren Daigle     Lauren Daigle
# 83            84    Paul McCartney    Paul McCartney
# 77            78  Carrie Underwood  Carrie Underwood
# 94            95     Nipsey Hussle     Nipsey Hussle
# 60            61           Normani           Normani
# 73            74     Blake Shelton     Blake Shelton
# 51            52          Ella Mai          Ella Mai
# 52            53    Bradley Cooper    Bradley Cooper
#
#                                                genres  popularity  \
# 91  ['rap', 'trap', 'underground hip hop', 'vapor ...          71
# 63                                        ['country']          73
# 46  ['ccm', 'christian alternative rock', 'christi...          75
# 83  ['album rock', 'art rock', 'beatlesque', 'clas...          75
# 77  ['contemporary country', 'country', 'country d...          76
# 94  ['conscious hip hop', 'gangster rap', 'hip hop...          76
# 60       ['dance pop', 'pop', 'post-teen pop', 'r&b']          77
# 73  ['contemporary country', 'country', 'country r...          78
# 51  ['dance pop', 'pop', 'pop r&b', 'pop rap', 'po...          78
# 52                                      ['hollywood']          78
#
#                               uri_spotify  followers
# 91  spotify:artist:2RDOrhPqAM4jzTRCEb19qX     981104
# 63  spotify:artist:60rpJ9SgigSd16DOAG7GSa     174200
# 46  spotify:artist:40LHVA5BTQp9RxHOQ9JPYj    1464851
# 83  spotify:artist:4STHEaNw4mPZ2tzheohgXB    3208871
# 77  spotify:artist:4xFUf1FHVy696Q1JQZMTRj    4222467
# 94  spotify:artist:0EeQBlQJFiAfJeVN2vT9s0    1750629
# 60  spotify:artist:2cWZOOzeOm4WmBJRnD5R7I    1015665
# 73  spotify:artist:1UTPBmNbXNTittyMJrNkvw    5382165
# 51  spotify:artist:7HkdQ0gt53LP4zmHsL0nap    3143752
# 52  spotify:artist:4VIvfOurcf0vuLRxLkGnIG     161775

# %%
## Bottom artists in terms of Spotify Followers
foll_sort_low_df = test_df.sort_values("followers", ascending=True)
foll_sort_low_df.head(10)
# Out:
#     2019_bb_rank      artist_name            name2  \
# 52            53   Bradley Cooper   Bradley Cooper
# 63            64  Billy Ray Cyrus  Billy Ray Cyrus
# 85            86     Maren Morris     Maren Morris
# 98            99     benny blanco     benny blanco
# 87            88          Mustard          Mustard
# 66            67    Morgan Wallen    Morgan Wallen
# 40            41         Swae Lee         Swae Lee
# 91            92        Sheck Wes        Sheck Wes
# 75            76       City Girls       City Girls
# 60            61          Normani          Normani
#
#                                                genres  popularity  \
# 52                                      ['hollywood']          78
# 63                                        ['country']          73
# 85          ['contemporary country', 'texas country']          80
# 98                   ['electropop', 'pop', 'pop rap']          85
# 87  ['cali rap', 'hip hop', 'pop rap', 'rap', 'sou...          83
# 66       ['contemporary country', 'deep talent show']          84
# 40          ['melodic rap', 'pop rap', 'rap', 'trap']          87
# 91  ['rap', 'trap', 'underground hip hop', 'vapor ...          71
# 75                  ['pop', 'scam rap', 'trap queen']          80
# 60       ['dance pop', 'pop', 'post-teen pop', 'r&b']          77
#
#                               uri_spotify  followers
# 52  spotify:artist:4VIvfOurcf0vuLRxLkGnIG     161775
# 63  spotify:artist:60rpJ9SgigSd16DOAG7GSa     174200
# 85  spotify:artist:6WY7D3jk8zTrHtmkqqo5GI     526346
# 98  spotify:artist:5CiGnKThu5ctn9pBxv7DGa     653196
# 87  spotify:artist:0YinUQ50QDB7ZxSCLyQ40k     766299
# 66  spotify:artist:4oUHIQIBe0LHzYfvXNW4QM     951179
# 40  spotify:artist:1zNqQNIdeOUZHb8zbZRFMX     961823
# 91  spotify:artist:2RDOrhPqAM4jzTRCEb19qX     981104
# 75  spotify:artist:37hAfseJWi0G3Scife12Il     991690
# 60  spotify:artist:2cWZOOzeOm4WmBJRnD5R7I    1015665

# %%
bins = [0, 19, 39, 59, 79, 100]

# Create labels for these bins
group_labels = ["1-20", "21-40", "41-60", "61-80", "81-100"]

pd.cut(test_df['2019_bb_rank'], bins, labels=group_labels).head()

test_df["Grouped BB Rank"] = pd.cut(test_df["2019_bb_rank"], bins, labels=group_labels)
test_df.head(100)
# Out:
#     2019_bb_rank    artist_name          name2  \
# 0              1    Post Malone    Post Malone
# 1              2  Ariana Grande  Ariana Grande
# 2              3  Billie Eilish  Billie Eilish
# 3              4         Khalid         Khalid
# 4              5          Drake          Drake
# ..           ...            ...            ...
# 95            96  Fleetwood Mac  Fleetwood Mac
# 96            97     The Weeknd     The Weeknd
# 97            98    Eric Church    Eric Church
# 98            99   benny blanco   benny blanco
# 99           100     Luke Bryan     Luke Bryan
#
#                                                genres  popularity  \
# 0                   ['dfw rap', 'melodic rap', 'rap']          95
# 1               ['dance pop', 'pop', 'post-teen pop']          99
# 2                               ['electropop', 'pop']          93
# 3                          ['alternative r&b', 'pop']          93
# 4   ['canadian hip hop', 'canadian pop', 'hip hop'...         100
# ..                                                ...         ...
# 95  ['album rock', 'classic rock', 'mellow gold', ...          88
# 96  ['canadian contemporary r&b', 'canadian pop', ...          96
# 97  ['contemporary country', 'country', 'country r...          78
# 98                   ['electropop', 'pop', 'pop rap']          85
# 99  ['contemporary country', 'country', 'country r...          80
#
#                               uri_spotify  followers Grouped BB Rank
# 0   spotify:artist:246dkjvS1zLTtiykXe5h60   29173640            1-20
# 1   spotify:artist:66CXWjxzNUsdJxJ2JdwvnR   52571724            1-20
# 2   spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH   34697267            1-20
# 3   spotify:artist:6LuN9FCkKOj5PcnpouEgny   12829933            1-20
# 4   spotify:artist:3TVXtAsR1Inumwj472S9r4   50593376            1-20
# ..                                    ...        ...             ...
# 95  spotify:artist:08GQAI4eElDnROBrJRGE0X    5464936          81-100
# 96  spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ   25562055          81-100
# 97  spotify:artist:2IvkS5MXK0vPGnwyJsrEyV    2745679          81-100
# 98  spotify:artist:5CiGnKThu5ctn9pBxv7DGa     653196          81-100
# 99  spotify:artist:0BvkDsjIUla7X0k6CSWh1I    5822742          81-100
#
# [100 rows x 8 columns]

# %%
BB_group = test_df.groupby("Grouped BB Rank")


# Get the average of each column within the GroupBy object
BB_group[["popularity", "followers"]].mean()
# Out:
#                  popularity     followers
# Grouped BB Rank
# 1-20              92.684211  2.233647e+07
# 21-40             87.850000  1.184395e+07
# 41-60             85.600000  9.951823e+06
# 61-80             83.950000  7.444834e+06
# 81-100            83.380952  5.534025e+06

# %%
new_groups = ["Ranks 1-20", "Ranks 21-40", "Ranks 41-60", "Ranks 61-80", "Ranks 81-100"]
pop_groups = [93, 88, 86, 84, 83]
plt.bar(new_groups, pop_groups, color="b", align="center")
plt.title("Popularity Means Across Billboard Ranked Artists")
plt.xlabel("Billboard Ranks")
plt.ylabel("Popularity Ranks")
# Out:
# Text(0, 0.5, 'Popularity Ranks')

# %%
## NEXT STEPS
##fix links?, Retitle columns
## Get frequency of genres-- recode into single genres? or split across cells?

## Analysis:
#BB Chart rank of top 10 artists and thier Spotify popularity numbers, and number of followers?
## What are the comparison stats of the bottom 10
## What types of musical genres are in the top 100 artists? What's the most popular genre amongst them?
## Is there a correlation between spotify rank and number of followers? with BB artist rank and followers?
##Create a final exported file with data and links?

# %%
## REST IS SAVED CODE FOR FUTURE USE

# %%
test_df = pd.Series(sum([item for item in "genres"], [])).value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-0e6152c42a09> in <module>
# ----> 1 test_df = pd.Series(sum([item for item in ["genres"]], [])).value_counts()
#
# TypeError: can only concatenate list (not "str") to list

# %%
genres_all = []
for x in 'genres':
    genres_all.append(x)

print(genres_all)
# Out:
# ['g', 'e', 'n', 'r', 'e', 's']

# %%
#### SAVED CODE DO NOT DELETE #spotify = spotipy.Spotify(auth_manager=SpotifyClientCredentials())

name = 'Taylor Swift'

results = spotify.search(q='artist:' + name, type='artist')
items = results['artists']['items']
if len(items) > 0:
    artist = items[0]
    print(artist['name'])
    print(artist['popularity'])
    print(artist['name'], artist['images'][0]['url'])
# Out:
# Taylor Swift
# 95
# Taylor Swift https://i.scdn.co/image/a37efbc7fd3f5f5df81b48ce9c6de53820b239c1

# %%
# Rename the headers to be more explanatory
renamed_df = reduced_df.rename(columns={"isbn": "ISBN",
                                        "original_title": "Original Title",
                                        "original_publication_year": "Publication Year",
                                        "authors": "Authors",
                                        "ratings_1": "One Star Reviews",
                                        "ratings_2": "Two Star Reviews",
                                        "ratings_3": "Three Star Reviews",
                                        "ratings_4": "Four Star Reviews",
                                        "ratings_5": "Five Star Reviews", })
renamed_df.head()
