# %%
# !pip install spotipy

import pandas as pd
import numpy as np
import requests
import json
import spotipy
from pprint import pprint
from spotipy.oauth2 import SpotifyClientCredentials
# Out:
# Requirement already satisfied: spotipy in c:\users\valerie\anaconda3\lib\site-packages (2.16.1)
# Requirement already satisfied: six>=1.10.0 in c:\users\valerie\anaconda3\lib\site-packages (from spotipy) (1.15.0)
# Requirement already satisfied: requests>=2.20.0 in c:\users\valerie\anaconda3\lib\site-packages (from spotipy) (2.24.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\valerie\anaconda3\lib\site-packages (from requests>=2.20.0->spotipy) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\valerie\anaconda3\lib\site-packages (from requests>=2.20.0->spotipy) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\valerie\anaconda3\lib\site-packages (from requests>=2.20.0->spotipy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\valerie\anaconda3\lib\site-packages (from requests>=2.20.0->spotipy) (1.25.9)

# %%
test_df = pd.read_csv("../Resources/billboard-2018-06-19.csv")
test_df.head()
# Out:
#    rank       song_name                          artist_name default  \
# 0     1   Nice For What                                Drake      +1
# 1     2          Psycho  Post Malone Featuring Ty Dolla $ign      -1
# 2     3       I Like It        Cardi B, Bad Bunny & J Balvin       -
# 3     4      God's Plan                                Drake      +1
# 4     5  Girls Like You           Maroon 5 Featuring Cardi B      -1
#
#   last_week  peak_rank  week_chart
# 0         2          1          10
# 1         1          1          16
# 2         3          3          10
# 3         5          1          21
# 4         4          4           3

# %%
test_df['name2'] = ""
test_df['genres'] = ""
test_df['popularity'] = ""
test_df['id'] = ""

test_df.head()
# Out:
#    rank       song_name                          artist_name default  \
# 0     1   Nice For What                                Drake      +1
# 1     2          Psycho  Post Malone Featuring Ty Dolla $ign      -1
# 2     3       I Like It        Cardi B, Bad Bunny & J Balvin       -
# 3     4      God's Plan                                Drake      +1
# 4     5  Girls Like You           Maroon 5 Featuring Cardi B      -1
#
#   last_week  peak_rank  week_chart name2 genres popularity id
# 0         2          1          10
# 1         1          1          16
# 2         3          3          10
# 3         5          1          21
# 4         4          4           3

# %%
user_id= 
token= 
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(user_id,token))

# %%
params= {
    "name2": "name", 
    "popularity": "popularity",
    "genres": "genres",
    "id": "external_urls"
}

# %%
for index, row in test_df[:50].iterrows():

    # get restaurant type from df
    person = row['artist_name']

    # add keyword to params dict
    params['keyword'] = person

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {person}.")
    results = spotify.search(q=f'artist: {person}', type='artist')
    
    artist_data = results['artists']['items']
    
    
    try:
        #print(f"Artist {person} is in dataset")
        #print(f"Trying to get name")
        test_df.loc[index, 'name2'] = artist_data[0]['name']
        #print(f"Trying to get popularity")
        test_df.loc[index, 'popularity'] = artist_data[0]['popularity']
        #print(f"Trying to get genres")
        #print(artist_data[0]['genres'])
        #print(type(artist_data[0]['genres']))
        test_df.loc[index, 'genres'] = str(artist_data[0]['genres'])
    except Exception as e:
        print(e)

# %%
test_df.loc[test_df['name2'] != '']
# Out:
#     rank               song_name       artist_name default last_week  \
# 0      1           Nice For What             Drake      +1         2
# 3      4              God's Plan             Drake      +1         5
# 5      6            Lucid Dreams        Juice WRLD      +3         9
# 6      7                Boo'd Up          Ella Mai      -1         6
# 8      9    No Tears Left To Cry     Ariana Grande      +4        13
# 11    12         This Is America  Childish Gambino      -5         7
# 14    15                    Mine             Bazzi      +8        23
# 15    16             In My Blood      Shawn Mendes      +4        20
# 16    17                 Perfect        Ed Sheeran      +4        21
# 18    19       Never Be The Same    Camila Cabello      -1        18
# 19    20              Better Now       Post Malone     +14        34
# 20    21       Whatever It Takes   Imagine Dragons      +1        22
# 21    22             Back To You      Selena Gomez      +9        31
# 22    23              Be Careful           Cardi B      +2        25
# 24    25                Delicate      Taylor Swift     +12        37
# 25    26                  Heaven        Kane Brown      +4        30
# 27    28               I'm Upset             Drake      +4        32
# 28    29                    Wait          Maroon 5      -3        26
# 30    31                All Mine        Kanye West     -20        11
# 31    32                 Tequila        Dan + Shay      +9        41
# 32    33               Plug Walk      Rich The Kid      +2        35
# 34    35               New Rules          Dua Lipa      +5        40
# 38    39                  Reborn   KIDS SEE GHOSTS       -         -
# 39    40                   Yikes        Kanye West     -32         8
# 40    41  All Girls Are The Same        Juice WRLD      +8        49
# 42    43                 Chun-Li       Nicki Minaj      +3        46
# 44    45         One Number Away        Luke Combs       -        45
# 45    46        I Like Me Better              Lauv      +7        53
# 46    47           Feel The Love   KIDS SEE GHOSTS       -         -
# 47    48               Get Along     Kenny Chesney      +8        56
#
#     peak_rank  week_chart             name2  \
# 0           1          10             Drake
# 3           1          21             Drake
# 5           6           5        Juice WRLD
# 6           6          11          Ella Mai
# 8           3           8     Ariana Grande
# 11          1           6  Childish Gambino
# 14         11          21             Bazzi
# 15         11          13      Shawn Mendes
# 16          1          42        Ed Sheeran
# 18          6          26    Camila Cabello
# 19          7           7       Post Malone
# 20         12          20   Imagine Dragons
# 21         22           5      Selena Gomez
# 22         11          11           Cardi B
# 24         25          14      Taylor Swift
# 25         15          25        Kane Brown
# 27         19           3             Drake
# 28         24          22          Maroon 5
# 30         11           2        Kanye West
# 31         32          14        Dan + Shay
# 32         13          18      Rich The Kid
# 34          6          46          Dua Lipa
# 38         39           1   KIDS SEE GHOSTS
# 39          8           2        Kanye West
# 40         41           5        Juice WRLD
# 42         10          10       Nicki Minaj
# 44         34          13        Luke Combs
# 45         46          18              Lauv
# 46         47           1   KIDS SEE GHOSTS
# 47         48          10     Kenny Chesney
#
#                                                genres popularity id
# 0   ['canadian hip hop', 'canadian pop', 'hip hop'...        100
# 3   ['canadian hip hop', 'canadian pop', 'hip hop'...        100
# 5                      ['chicago rap', 'melodic rap']         99
# 6   ['pop', 'pop r&b', 'pop rap', 'r&b', 'rap', 'u...         78
# 8               ['dance pop', 'pop', 'post-teen pop']         99
# 11       ['atl hip hop', 'hip hop', 'pop rap', 'rap']         82
# 14                           ['pop', 'post-teen pop']         83
# 15  ['canadian pop', 'dance pop', 'pop', 'post-tee...         91
# 16                                  ['pop', 'uk pop']         93
# 18  ['dance pop', 'pop', 'pop dance', 'post-teen p...         87
# 19                  ['dfw rap', 'melodic rap', 'rap']         95
# 20                     ['modern rock', 'pop', 'rock']         90
# 21  ['dance pop', 'pop', 'pop dance', 'post-teen p...         90
# 22                          ['pop', 'pop rap', 'rap']         93
# 24  ['dance pop', 'pop', 'pop dance', 'post-teen p...         95
# 25           ['contemporary country', 'country road']         83
# 27  ['canadian hip hop', 'canadian pop', 'hip hop'...        100
# 28                                ['pop', 'pop rock']         90
# 30                             ['chicago rap', 'rap']         92
# 31                    ['contemporary country', 'pop']         81
# 32  ['atl hip hop', 'hip hop', 'melodic rap', 'pop...         80
# 34        ['dance pop', 'pop', 'pop dance', 'uk pop']         94
# 38          ['hip hop', 'rap', 'underground hip hop']         68
# 39                             ['chicago rap', 'rap']         92
# 40                     ['chicago rap', 'melodic rap']         99
# 42  ['dance pop', 'hip pop', 'pop', 'pop dance', '...         92
# 44                           ['contemporary country']         88
# 45                           ['pop', 'post-teen pop']         88
# 46          ['hip hop', 'rap', 'underground hip hop']         68
# 47  ['contemporary country', 'country', 'country r...         77

# %%
#spotify = spotipy.Spotify(auth_manager=SpotifyClientCredentials())

name = 'Taylor Swift'

results = spotify.search(q='artist:' + name, type='artist')
items = results['artists']['items']
if len(items) > 0:
    artist = items[0]
    print(artist['name'])
    print(artist['popularity'])
    print(artist['name'], artist['images'][0]['url'])
# Out:
# Taylor Swift
# 95
# Taylor Swift https://i.scdn.co/image/a37efbc7fd3f5f5df81b48ce9c6de53820b239c1
